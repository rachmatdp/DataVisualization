# %% [markdown]
# <a href="https://colab.research.google.com/github/rachmatdp/DataVisualization/blob/master/Midterm_Project_RachmatDwiPutra_1301180201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tugas Besar 1
# ### MK Visualisasi Data Gasal 2020/2021

# %% [markdown]
# <b>Nama<b>: <b>RACHMAT DWI PUTRA<b> <br>
# <b>NIM<b>: <B>1301180201<B>

# %% [markdown]
# #### Aturan umum:
# 1. Setiap soal dievaluasi berdasarkan _code program_ dan penjelasan yang dibuat.
# 2. File _midterm project_ yang telah dikerjakan harus di-submit melalui LMS.
# 3. Batas akhir submit file adalah 4 April 2021 pukul 23:59.
# 4. <b><font color='red'>Setiap tindakan plagiarism akan berakibat pada ketidaklulusan pada MK ini.</font><b>

# %% [markdown]
# ### Kasus 1: Pima Indian Diabetes Data Set (Soal 1 - 2)
# Dataset ini berasal dari the National Institute of Diabetes and Digestive and Kidney Diseases. Tujuan dari pengumpulan dataset ini untuk dapat memprediksi secara diagnosis apakah seseorang mengidap penyakit diabetes atau tidak berdasarkan beberapa pengukuran diagnostik. Seluruh pasien pada dataset ini adalah perempuan keturunan India Pima yang berumur kurang dari 21 tahun.<br><br>
# Dataset terdiri dari beberapa variabel prediktor medis dan satu variabel target sebagai _outcome_. Variabel prediktor di antaranya jumlah kehamilan, BMI, level insulin, usia, dll.lin level, age, and so on. Dataset dapat diunduh melalui [tautan ini](https://www.dl.dropboxusercontent.com/s/3i3gfr8pih4jwd4/diabetes.csv?dl=0)

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Soal 1 (15 poin)
# Tampilkan visualisasi distribusi data untuk variabel "Glucose" dan "Insulin", lalu jelaskan hasil distribusinya.

# %% [markdown]
# #### Code

# %%
# type your code here
# 1301180201

# Membaca dataset diabetes.csv
df = pd.read_csv('https://www.dl.dropboxusercontent.com/s/3i3gfr8pih4jwd4/diabetes.csv?dl=0')

# Mengisi nilai yang kosong dengan Mean
df = df.fillna(df.mean())

# Mendapatkan data khusus variabel Glucose dan Insulin
df_GI = df[['Glucose','Insulin']] 

# Membuat Histogram untuk membandingkan distribusi angka Glucose dan Insulin
df_GI[['Glucose', 'Insulin']].hist(color = "maroon", figsize = (12,12));

print(df_GI.describe())
# Out:
#           Glucose     Insulin
# count  768.000000  768.000000
# mean   120.894531   79.799479
# std     31.972618  115.244002
# min      0.000000    0.000000
# 25%     99.000000    0.000000
# 50%    117.000000   30.500000
# 75%    140.250000  127.250000
# max    199.000000  846.000000

# %% [markdown]
# #### Penjelasan
# Langkah pertama yang perlu dilakukan adalah dengan melakukan import library Pandas yang didalam nya sudah terdapat fungsi untuk membaca Data dengan Dataframe sekaligus melakukan plotting terhadap data yang ada serta melakukan Pre-Processing Data. Untuk memberikan hasil yang baik maka perlu menghilangkan nilai null, jadi saya memilih untuk mengganti nilai Null dengan nilai Mean pada kolom tersebut. Lalu membuat dataframe baru yang berisikan dataframe df yang berisikan khusus Glucose dan Insulin.
#
# Selanjutnya, saya menggunakan Histogram sebagai metode visualisasi data tersebut. Dari Histogram di atas, dapat disimpulkan bahwa Dari Jumlah 768 Pasien didapatkan Nilai Max dan Minimum yang dimiliki oleh Glucose adalah 0 dan 199, sedangkan untuk Insulin adalah 0 dan 846. Rata-rata nilai Glucose yang dimiliki oleh semua Pasien adalah 120,89 dan Insulin yaitu 79,79. Dari gambar juga dapat dikatakan bahwa Variable Glucose berdistribusi normal hanya saja terdapat angka 0 yang bisa jadi sebuah pencilan atau outlier, sedangkan Variable Insulin berdasarkan plot distribusinya memiliki skewness positif atau skew ke kanan.

# %% [markdown]
# ### Soal 2 (25 poin)
# Tampilkan visualisasi dari korelasi (i) antar variabel dan (ii) antara variabel dan target, lalu jelaskan hasil korelasinya.

# %% [markdown]
# #### Code

# %%
# type your code here
# 1301180201

df_kor1 = df.drop(['Outcome'], axis=1) # Membuat dataframe baru selain Outcome
df_kor2 = df

# Korelasi 1
korelasi1 = df_kor1.corr()

# Korelasi 2
korelasi2 = df_kor2.corr()[['Outcome']]

# Subplot
plt.figure(figsize=(12, 6))
plt.subplot(121)   #  subplot pertama
plt.title('Korelasi 1 : Antar Variabel tanpa Outcome')
sn.heatmap(korelasi1, annot=True, fmt='.2f', 
           square=True, cmap = 'Greens_r')

plt.subplot(122)   #  subplot kedua
plt.title('Korelasi 2 : Variabel dengan Outcome')
sn.heatmap(korelasi2.sort_values(by='Outcome', ascending=False), 
           vmin=-1, vmax=1, annot=True, fmt='.2f', 
           square=True, cmap = 'Blues_r')

plt.show()

# %% [markdown]
# #### Penjelasan
# <b> Untuk Korelasi 1 :</b><br>
# Diperlukan dataframe yang berisikan seluruh variabel/kolom selain Outcome. Setelah itu dengan menggunakan fungsi corr() kita dapat menghitung korelasi antar variabel, dan masukkan hasil fungsi tersebut kedalam Heatmap untuk divisualisasikan. Hasil dari visualisasi tersebut secara keseluruhan dapat dilihat korelasi dari satu variable dengan variable lainnya selain variable target (Outcome) memiliki nilai korelasi yang berbeda-beda yaitu ada yang negatif dan positif, tetapi tidak ada yang memiliki nilai korelasi tinggi atau kuat yang paling tinggi hanya 0.54, yaitu variabel Age dan Pregnancies. <br>
#
# <b> Untuk Korelasi 2 :</b><br>
#
# Adapun perbandingan secara visual antara variabel dengan outcome dapat dilihat bahwa salah satu variabel yang sangat mempengaruhi Outcome (Diabetes) yaitu variabel Glucose yang memiliki nilai yang paling tinggi dalam menentukan seseorang menderita Diabetes atau tidak. Untuk variabel yang paling kecil (tidak mempengaruhi Diabetes) adalah SkinThickness dan BloodPressure dengan nilai 0.07.

# %% [markdown]
# ### Kasus 2: Stock Market Analysis (Soal 3 - 4)
# Pada kasus ini, kita akan membandingkan beberapa parameter yang diturunkan dari data historis harga saham dari 3 perusahaan, yaitu Nasdaq, Nikkei dan Hang Seng. Data set dapat diunduh melalui [tautan ini](https://www.dl.dropboxusercontent.com/s/0wny6x5sio9nvap/stock_market.zip?dl=0).

# %% [markdown]
# ### Soal 3 (30 poin)
# Lakukanlah _trend analysis_ nilai _daily percentage change_ dari ketiga harga saham tersebut selama tahun 2019, lalu tampilkan dan jelaskan melalui visualisasi data.
# _Trend analysis_ dilakukan dengan menggunakan hubungan berikut:
# ![output%2011.png](https://www.dl.dropboxusercontent.com/s/dxmrm74ksz5l9v2/trend_analysis_fig.png?dl=0)

# %% [markdown]
# #### Code

# %%
# type your code here
# 1301180201

# Melakukan Import Dataset
df_nasdaq = pd.read_csv('/content/sample_data/Nasdaq.csv')
df_hang = pd.read_csv('/content/sample_data/Hang_Seng.csv')
df_nikkei = pd.read_csv('/content/sample_data/Nikkei.csv')


# Melakukan drop baris yang memiliki nilai null
df_nasdaq = df_nasdaq.dropna(axis = 0)
df_hang = df_hang.dropna(axis = 0)
df_nikkei = df_nikkei.dropna(axis = 0)

# Mengubah tipe data fitur date dan menyimpan ke dalam indeks date
df_nasdaq['Date'] = pd.to_datetime(df_nasdaq['Date'])
df_hang['Date'] = pd.to_datetime(df_hang['Date'])
df_nikkei['Date'] = pd.to_datetime(df_nikkei['Date'])
df_nasdaq.index = df_nasdaq["Date"]
df_hang.index = df_hang["Date"]
df_nikkei.index = df_nikkei["Date"]

# Membuat Kolom 'Day_Perc_Change'
df_nasdaq["Day_Perc_Change"] = df_nasdaq["Adj Close"].pct_change()*100
df_hang["Day_Perc_Change"] = df_hang["Adj Close"].pct_change()*100
df_nikkei["Day_Perc_Change"] = df_nikkei["Adj Close"].pct_change()*100

# Karena "Date" bersifat duplicate, sehingga akan di drop salah satu
df_nasdaq = df_nasdaq.drop(['Date'], axis=1)
df_hang = df_hang.drop(['Date'], axis=1)
df_nikkei = df_nikkei.drop(['Date'], axis=1)

# Menghapus baris data yang bernilai null
df_nasdaq = df_nasdaq.dropna(axis = 0)
df_hang = df_hang.dropna(axis = 0)
df_nikkei = df_nikkei.dropna(axis = 0)

# Trend Analysis
def trend(x):
    if x > -0.5 and x <= 0.5:
        return "Slight or No change"
    elif x > 0.5 and x <= 1:
        return "Slight Positive"
    elif x > -1 and x <= -0.5:
        return "Slight Negative"
    elif x > 1 and x <= 3:
        return "Positive"
    elif x > -3 and x <= -1:
        return "Negative"
    elif x > 3 and x <= 7:
        return "Among top gainers"
    elif x > -7 and x <= -3:
        return "Among top losers"
    elif x > 7:
        return "Bull run"
    elif x <= -7:
        return "Bear drop"

# Menambahkan kolom trend
df_nasdaq["Trend"]= df_nasdaq["Day_Perc_Change"].apply(lambda x:trend(x))
df_hang["Trend"]= df_hang["Day_Perc_Change"].apply(lambda x:trend(x))
df_nikkei["Trend"]= df_nikkei["Day_Perc_Change"].apply(lambda x:trend(x))

# Mengambil data Stock Market khusus tahun 2019
df_nasdaq = df_nasdaq['2019-01-01' : '2019-12-31']
df_hang = df_hang['2019-01-01' : '2019-12-31']
df_nikkei = df_nikkei['2019-01-01' : '2019-12-31']

# %%
# SUBPLOT UNTUK NASDAQ
plt.subplot(131)   
plt.title('TREND ANALYSIS SAHAM NASDAQ', y=1.5)
pie_nasdaq = df_nasdaq.groupby('Trend')
pie_label = sorted([i for i in df_nasdaq.loc[:, 'Trend'].unique()])
plt.pie(pie_nasdaq['Trend'].count(), shadow=True, labels=None, autopct = '%1.1f%%', radius = 2, pctdistance=1.12)
plt.legend(labels=pie_label, loc='upper left', bbox_to_anchor = (1.5, 1)) 
plt.show()

# %%
# SUBPLOT UNTUK HANG SENG
plt.subplot(132) 
plt.title('TREND ANALYSIS SAHAM HANG SENG', y=1.5)
pie_hang = df_hang.groupby('Trend')
pie_label = sorted([i for i in df_hang.loc[:, 'Trend'].unique()])
plt.pie(pie_hang['Trend'].count(), shadow=True, labels=None, autopct = '%1.1f%%', radius = 2, pctdistance=1.12)
plt.legend(labels=pie_label, loc='upper left', bbox_to_anchor = (1.5, 1)) 
plt.show()

# %%
# SUBPLOT UNTUK NIKKEI
plt.subplot(133) 
plt.title('TREND ANALYSIS SAHAM NIKKEI', y=1.5)
pie_nikkei = df_nikkei.groupby('Trend')
pie_label = sorted([i for i in df_nikkei.loc[:, 'Trend'].unique()])
plt.pie(pie_nikkei['Trend'].count(), shadow=True, labels=None, autopct = '%1.1f%%', radius = 2, pctdistance=1.12)
plt.legend(labels=pie_label, loc='upper left', bbox_to_anchor = (1.5, 1)) 
plt.show()

# %% [markdown]
# #### Penjelasan
# Pada 3 saham yang diberikan datasetnya, untuk soal ini kita menentukan trend analysis yang dimilikinya. Dari hasil visualisasi dengan pie chart diatas, kita dapat menyimpulkan bahwa saham NASDAQ lebih baik dibandingan yang lainnya. Hal ini dapat kita lihat bahwa sebesar 17.1% dari periode waktu di Tahun 2019 stock market saham NASDAQ memiliki kenaikan harga (Positif). Sedangkan saham HANG SENG hanya sebesar 13.0% dan NIKKEI 11.6%. Sementara itu, stock market yang memiliki penurunan harga saham terbanyak ada pada saham HANG SENG, sebesar 12.2% dari periode Tahun 2019 terjadi penurunan harga (Negative). Selain itu, pada saham NIKKEI dapat dikatakan stabil, sekitar 52.7% dari periode waktunya hampir tidak ada perubahan harga (Slight or No change).

# %% [markdown]
# ### Soal 4 (30 poin)
# Lakukanlah analisis volatilitas dari ketiga harga saham tersebut selama tahun 2019, lalu tampilkan dan jelaskan hasil visualisasinya.

# %% [markdown]
# #### Code

# %%
# type your code here
# 1301180201

df_combine = pd.concat([df_nasdaq ["Adj Close"],df_nikkei["Adj Close"], df_hang["Adj Close"]], axis =1)
df_combine.columns = ["NASDAQ","NIKKEI","HANG SENG"]
df_combine.dropna(inplace=True, axis=0)

df_perc_chg = df_gabung.pct_change()*100
df_perc_chg.dropna(inplace = True, how="any", axis = 0)

df_combine_vol = df_perc_chg[["Nasdaq","Nikkei","Hang_Seng"]].rolling(7).std()*np.sqrt(7)
df_combine_vol.plot(figsize = (16,8))
plt.show()

# %% [markdown]
# #### Penjelasan
# Pada 3 dataset saham tersebut, akan digabungkan dalam satu dataframe untuk dicari nilai volatilitas berdasarkan nilai adj close (pendekatan) yang ada di setiap dataset saham tersebut. Dari visualisasi data diatas dapat disimpulkan bahwa nilai volatilitas dari saham NASDAQ memilki nilai volatilitas tertinggi dibanding dengan saham yang lainnya,  namun fluktuasinya lebih banyak negative atau penurunan. sedangkan saham NIKKEI memiliki fluktuasi yang cenderung naik atau positif sehingga bisa dikatakan saham ini cukup stabil, begitu pula dengan saham HANG SENG.
